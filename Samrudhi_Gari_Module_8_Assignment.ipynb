# %% [markdown]
# <a href="https://colab.research.google.com/github/Samrudhig/DS-Colab-Stuff/blob/main/Samrudhi_Gari_Module_8_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 8 Assignment
#
# Samrudhi Gari
#
# ## Overview

# %% [markdown]
# Be sure to replace the stud_id variable with you student id. Automatic 0 if not properly replaced.

# %%
# create seed, run this cell as is, only edit your stud_id
import pandas as pd
import numpy as np
import pandas as pd
import string
import random
import re
from sklearn.datasets import make_regression

n = 500

def make_null(r, w):
    # rtn = random.choices([np.nan, r])
    wi = w * .1
    rtn = np.random.choice([r, np.NaN], p=[1-wi, wi])
    return re.sub(r"[\[\]]",'', str(rtn))


# provide your student id as stud_id, replace 123456789 (automatice 0 if not replaced with your student id)
stud_id = 123456789
my_seed = random.seed(11687267)

# Do not edit this cell beyond this line
variables = [''.join(random.choices(string.ascii_lowercase, k=4)) for _ in range(30)]
print(variables)

X, y = make_regression(n_samples=n, n_features=20, n_informative=12)
# random.shuffle(variables)
cols = variables[:20]
df = pd.DataFrame(data=X, columns=cols)
df[cols[0]] = round(df[cols[0]], 4)
df[variables[20]] = 0.03
df[variables[21]] = 0.07
df[variables[22]] = df[variables[0]]
df[variables[23]] = df[cols[1]]
df[variables[24]] = df[variables[20]].apply(make_null, args=(1,))
df[variables[25]] = df[variables[13]].apply(make_null, args=(1,))
df[variables[26]] = random.sample(range(100, 1000), k=n)
df[variables[27]] = random.sample(range(1000, 10000), k=n)
df[variables[28]] = np.random.choice([.4, .1], p=[.98, .02])

df[variables[7]] = df[variables[7]].apply(lambda r: abs(r) if (r < -0.03) else r)
df[variables[8]] = df[variables[8]].apply(lambda r: abs(r)*-1 if (r > 0.02) else r)
df[variables[9]] = df[variables[9]].apply(lambda r: abs(r) if (r < -0.01) else r)
df[variables[7]] = df[variables[7]].apply(make_null, args=(1,))
df[variables[8]] = df[variables[8]].apply(make_null, args=(1,))
df[variables[9]] = df[variables[9]].apply(make_null, args=(1,))
df[variables[17]] = df[variables[17]].apply(make_null, args=(1,))
df[variables[18]] = df[variables[18]].apply(make_null, args=(1,))
df[variables[19]] = df[variables[19]].apply(make_null, args=(1,))

df = df[np.random.default_rng(seed=my_seed).permutation(df.columns.values)]

df = df.assign(survival=[random.choice(['x', 'o']) for i in range(n)])
df = df.assign(treatment=[random.choice(['yes', 'no']) for i in range(n)])
df = df.assign(level=[random.choice(['level 1', 'level 2', 'level 3']) for i in range(n)])
df = df.assign(stage=[random.choice(['stage 5', 'stage 4', 'stage 3', 'stage 2', 'stage 1']) for i in range(n)])

df['target'] = y

dupes = df.loc[0:10]
df = pd.concat([df, dupes], axis=0)

df = df.sample(frac=1).reset_index(drop=True)

#df.to_csv('Assignment 8.csv', index=False) # comment this out after successful run so that you don't overwrite your data
# Out:
# ['ljrp', 'vmck', 'wlie', 'hrqg', 'hvgk', 'bfze', 'levm', 'mvtf', 'amvq', 'jycc', 'oaug', 'szif', 'ialq', 'xvft', 'ufpi', 'txnv', 'jngw', 'vhkq', 'zdku', 'ojap', 'ivzz', 'pjio', 'jmam', 'msts', 'snbt', 'setk', 'bfgt', 'jjyc', 'vajy', 'xqys']

# %%
# read the dataset created above into a datagrame and output shape, info, and head
df =  pd.read_csv("Assignment 8.csv")
print("shape of the data frame is: ", df.shape)
print("Info of the Dataframe is: ",df.info())
df.head()
# Out:
# shape of the data frame is:  (511, 34)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 511 entries, 0 to 510
# Data columns (total 34 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   jmam       511 non-null    float64
#  1   vhkq       459 non-null    float64
#  2   bfze       511 non-null    float64
#  3   msts       511 non-null    float64
#  4   hvgk       511 non-null    float64
#  5   zdku       464 non-null    float64
#  6   oaug       511 non-null    float64
#  7   bfgt       511 non-null    int64
#  8   jycc       445 non-null    float64
#  9   jjyc       511 non-null    int64
#  10  setk       462 non-null    float64
#  11  ojap       460 non-null    float64
#  12  szif       511 non-null    float64
#  13  jngw       511 non-null    float64
#  14  mvtf       463 non-null    float64
#  15  pjio       511 non-null    float64
#  16  levm       511 non-null    float64
#  17  vmck       511 non-null    float64
#  18  snbt       460 non-null    float64
#  19  xvft       511 non-null    float64
#  20  ivzz       511 non-null    float64
#  21  wlie       511 non-null    float64
#  22  ljrp       511 non-null    float64
#  23  vajy       511 non-null    float64
#  24  hrqg       511 non-null    float64
#  25  ufpi       511 non-null    float64
#  26  txnv       511 non-null    float64
#  27  ialq       511 non-null    float64
#  28  amvq       459 non-null    float64
#  29  survival   511 non-null    object
#  30  treatment  511 non-null    object
#  31  level      511 non-null    object
#  32  stage      511 non-null    object
#  33  target     511 non-null    float64
# dtypes: float64(28), int64(2), object(4)
# memory usage: 135.9+ KB
# Info of the Dataframe is:  None
#      jmam      vhkq      bfze      msts      hvgk      zdku      oaug  bfgt  \
# 0  2.2715 -2.320007  0.467554 -0.074303 -0.338688  0.192961  0.029586   933
# 1 -0.4287 -0.493525 -0.802143  1.437894  0.460774  0.378646  1.197845   408
# 2 -0.5901 -2.014887  0.282173  0.076346  0.586560 -0.540005  0.569500   656
# 3  0.5769 -0.521844  0.283896  0.978932  0.892733 -0.293994 -1.726094   424
# 4 -0.6207  0.526562 -0.586000 -0.969111  0.017440  1.350980 -1.480205   949
#
#        jycc  jjyc  ...      hrqg      ufpi      txnv      ialq      amvq  \
# 0       NaN  4622  ... -1.649761  1.003410  1.149512  1.609555 -0.264469
# 1  0.148960  9637  ... -0.572065  0.216728 -0.583962 -1.890174 -0.140201
# 2  1.140327  1919  ...  0.400968  0.243072  0.858683  1.593868 -0.554054
# 3  0.756425  7512  ... -0.367417 -0.311685  0.647631 -1.610998 -1.029694
# 4  1.366351  8765  ... -0.684355 -0.620242 -0.875133 -0.457401 -0.178643
#
#    survival  treatment    level    stage      target
# 0         o         no  level 3  stage 1  215.226411
# 1         o        yes  level 2  stage 3 -313.897054
# 2         o        yes  level 1  stage 3  -58.535239
# 3         o        yes  level 3  stage 3  -84.298136
# 4         x         no  level 3  stage 1 -328.992688
#
# [5 rows x 34 columns]

# %%
df.isna().sum()
# Out:
# jmam          0
# vhkq         52
# bfze          0
# msts          0
# hvgk          0
# zdku         47
# oaug          0
# bfgt          0
# jycc         66
# jjyc          0
# setk         49
# ojap         51
# szif          0
# jngw          0
# mvtf         48
# pjio          0
# levm          0
# vmck          0
# snbt         51
# xvft          0
# ivzz          0
# wlie          0
# ljrp          0
# vajy          0
# hrqg          0
# ufpi          0
# txnv          0
# ialq          0
# amvq         52
# survival      0
# treatment     0
# level         0
# stage         0
# target        0
# dtype: int64

# %%
constants = [ x for x in df.columns if len(df[x].fillna(0).unique()) == 1 ]

constants
# Out:
# ['pjio', 'ivzz', 'vajy']

# %%
df.drop(constants, axis=1, inplace=True)
df.shape
# Out:
# (511, 31)

# %%
# output and drop constants
df['zdku']
# Out:
# 0      0.192961
# 1      0.378646
# 2     -0.540005
# 3     -0.293994
# 4      1.350980
#          ...
# 506   -0.644166
# 507   -1.464212
# 508    1.382362
# 509    0.968402
# 510         NaN
# Name: zdku, Length: 511, dtype: float64

# %%
quasi_constants = []
for val in df.columns.sort_values():
    if (len(df[val].unique()) < 3):
        val_counts = df[val].value_counts(normalize=True)
        print(val_counts)
        if list(val_counts)[0] > 0.98:
            quasi_constants.append(val)

print('quasi_constants: ', quasi_constants)
# Out:
# 0.03    1.0
# Name: snbt, dtype: float64
# o    0.502935
# x    0.497065
# Name: survival, dtype: float64
# yes    0.508806
# no     0.491194
# Name: treatment, dtype: float64
# quasi_constants:  ['snbt']

# %%
# output quasi constants and drop quasi constants (don't drop bi-label features)
print("shape of the df before the dropping Quasi Constant columns:", df.shape)
df.drop(quasi_constants,axis = 1,inplace =True)
print("shape of the df after the dropping Quasi Constant columns:", df.shape)
df.info()
# Out:
# shape of the df before the dropping Quasi Constant columns: (511, 31)
# shape of the df after the dropping Quasi Constant columns: (511, 30)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 511 entries, 0 to 510
# Data columns (total 30 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   jmam       511 non-null    float64
#  1   vhkq       459 non-null    float64
#  2   bfze       511 non-null    float64
#  3   msts       511 non-null    float64
#  4   hvgk       511 non-null    float64
#  5   zdku       464 non-null    float64
#  6   oaug       511 non-null    float64
#  7   bfgt       511 non-null    int64
#  8   jycc       445 non-null    float64
#  9   jjyc       511 non-null    int64
#  10  setk       462 non-null    float64
#  11  ojap       460 non-null    float64
#  12  szif       511 non-null    float64
#  13  jngw       511 non-null    float64
#  14  mvtf       463 non-null    float64
#  15  levm       511 non-null    float64
#  16  vmck       511 non-null    float64
#  17  xvft       511 non-null    float64
#  18  wlie       511 non-null    float64
#  19  ljrp       511 non-null    float64
#  20  hrqg       511 non-null    float64
#  21  ufpi       511 non-null    float64
#  22  txnv       511 non-null    float64
#  23  ialq       511 non-null    float64
#  24  amvq       459 non-null    float64
#  25  survival   511 non-null    object
#  26  treatment  511 non-null    object
#  27  level      511 non-null    object
#  28  stage      511 non-null    object
#  29  target     511 non-null    float64
# dtypes: float64(24), int64(2), object(4)
# memory usage: 119.9+ KB

# %%
# output and drop duplicate rows, print shape
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 506    False
# 507    False
# 508    False
# 509    False
# 510    False
# Length: 511, dtype: bool

# %%
# check of duplicate columns
print("shape before: ",df.shape)
df.drop_duplicates(inplace = True)
print("shape after: ",df.shape)
# Out:
# shape before:  (511, 30)
# shape after:  (500, 30)

# %%
# drop duplicate features and output shape
duplicate_columns = []
for i in range(0, len(df.columns)):
    original = df.columns[i]

    for duplicate in df.columns[i + 1:]:
        if df[original].equals(df[duplicate]):
            duplicate_columns.append(duplicate)
            print(f'{original} looks the same as {duplicate}')

duplicate_columns
# Out:
# jmam looks the same as ljrp
# msts looks the same as vmck
# ['ljrp', 'vmck']

# %%
print("shape before: ",df.shape)
df.drop(duplicate_columns, axis=1, inplace = True)
print("shape after: ",df.shape)
df.info()
# Out:
# shape before:  (500, 30)
# shape after:  (500, 28)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 510
# Data columns (total 28 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   jmam       500 non-null    float64
#  1   vhkq       449 non-null    float64
#  2   bfze       500 non-null    float64
#  3   msts       500 non-null    float64
#  4   hvgk       500 non-null    float64
#  5   zdku       453 non-null    float64
#  6   oaug       500 non-null    float64
#  7   bfgt       500 non-null    int64
#  8   jycc       437 non-null    float64
#  9   jjyc       500 non-null    int64
#  10  setk       454 non-null    float64
#  11  ojap       450 non-null    float64
#  12  szif       500 non-null    float64
#  13  jngw       500 non-null    float64
#  14  mvtf       452 non-null    float64
#  15  levm       500 non-null    float64
#  16  xvft       500 non-null    float64
#  17  wlie       500 non-null    float64
#  18  hrqg       500 non-null    float64
#  19  ufpi       500 non-null    float64
#  20  txnv       500 non-null    float64
#  21  ialq       500 non-null    float64
#  22  amvq       448 non-null    float64
#  23  survival   500 non-null    object
#  24  treatment  500 non-null    object
#  25  level      500 non-null    object
#  26  stage      500 non-null    object
#  27  target     500 non-null    float64
# dtypes: float64(22), int64(2), object(4)
# memory usage: 113.3+ KB

# %% [markdown]
# ### Imputation
#
# Use histograms to view the shape of your numerical features.
# * Use median to replace missing data for skewed features
# * Use interpolation to replace missing data for features that look normal

# %%
# plot histograms
import matplotlib.pyplot as plt

df.hist()
plt.tight_layout();

# %%
# show null values for each variable
df.isnull().sum()
# Out:
# jmam          0
# vhkq         51
# bfze          0
# msts          0
# hvgk          0
# zdku         47
# oaug          0
# bfgt          0
# jycc         63
# jjyc          0
# setk         46
# ojap         50
# szif          0
# jngw          0
# mvtf         48
# levm          0
# xvft          0
# wlie          0
# hrqg          0
# ufpi          0
# txnv          0
# ialq          0
# amvq         52
# survival      0
# treatment     0
# level         0
# stage         0
# target        0
# dtype: int64

# %%
# print info to recall which variables are numeric vs categorical
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 510
# Data columns (total 28 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   jmam       500 non-null    float64
#  1   vhkq       449 non-null    float64
#  2   bfze       500 non-null    float64
#  3   msts       500 non-null    float64
#  4   hvgk       500 non-null    float64
#  5   zdku       453 non-null    float64
#  6   oaug       500 non-null    float64
#  7   bfgt       500 non-null    int64
#  8   jycc       437 non-null    float64
#  9   jjyc       500 non-null    int64
#  10  setk       454 non-null    float64
#  11  ojap       450 non-null    float64
#  12  szif       500 non-null    float64
#  13  jngw       500 non-null    float64
#  14  mvtf       452 non-null    float64
#  15  levm       500 non-null    float64
#  16  xvft       500 non-null    float64
#  17  wlie       500 non-null    float64
#  18  hrqg       500 non-null    float64
#  19  ufpi       500 non-null    float64
#  20  txnv       500 non-null    float64
#  21  ialq       500 non-null    float64
#  22  amvq       448 non-null    float64
#  23  survival   500 non-null    object
#  24  treatment  500 non-null    object
#  25  level      500 non-null    object
#  26  stage      500 non-null    object
#  27  target     500 non-null    float64
# dtypes: float64(22), int64(2), object(4)
# memory usage: 113.3+ KB

# %%
# replace missing data with appropriate mean, median, or mode and confirm with isnull().sum()
numeric_columns = df.select_dtypes(include=['number']).columns
categorical_columns = df.select_dtypes(include=['object']).columns

for column in numeric_columns:
    if df[column].skew() > 1.0:
        median = df[column].median()
        df[column].fillna(median, inplace=True)
    else:
        mean = df[column].mean()
        df[column].fillna(mean, inplace=True)

for column in categorical_columns:
    mode = df[column].mode()[0]
    df[column].fillna(mode, inplace=True)
null_counts = df.isnull().sum()
print(null_counts)
# Out:
# jmam         0
# vhkq         0
# bfze         0
# msts         0
# hvgk         0
# zdku         0
# oaug         0
# bfgt         0
# jycc         0
# jjyc         0
# setk         0
# ojap         0
# szif         0
# jngw         0
# mvtf         0
# levm         0
# xvft         0
# wlie         0
# hrqg         0
# ufpi         0
# txnv         0
# ialq         0
# amvq         0
# survival     0
# treatment    0
# level        0
# stage        0
# target       0
# dtype: int64

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    df.drop('target', axis=1),
    df['target'],
    test_size=0.25,
    random_state=42)

# %% [markdown]
# **Important:** We will not be using df (the dataframe we created above) for the remaining code. Instead we will be using X_train for df and X_test when appropriate.

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# describe X_train
X_train.describe()
# Out:
#              jmam        vhkq        bfze        msts        hvgk        zdku  \
# count  375.000000  375.000000  375.000000  375.000000  375.000000  375.000000
# mean    -0.052152    0.058521   -0.010869    0.013767    0.030813    0.036686
# std      0.965035    0.942168    0.943810    0.980027    1.006022    0.878809
# min     -3.081500   -4.019715   -2.938783   -2.478928   -2.696013   -3.042598
# 25%     -0.650450   -0.553456   -0.637562   -0.663000   -0.580452   -0.482225
# 50%     -0.087900    0.004336    0.009779   -0.038333   -0.010641    0.014956
# 75%      0.557150    0.650061    0.581011    0.655593    0.665284    0.593276
# max      2.892300    2.881825    2.788130    2.908620    2.862135    2.763532
#
#              oaug        bfgt        jycc         jjyc  ...        jngw  \
# count  375.000000  375.000000  375.000000   375.000000  ...  375.000000
# mean    -0.039508  563.813333    0.848221  5541.605333  ...   -0.021014
# std      1.037949  268.230959    0.530156  2697.003944  ...    1.026857
# min     -3.047022  100.000000    0.012032  1016.000000  ...   -3.212358
# 25%     -0.780126  325.500000    0.449896  3279.000000  ...   -0.561123
# 50%     -0.027025  580.000000    0.836854  5484.000000  ...   -0.043020
# 75%      0.682306  789.500000    1.171733  7937.000000  ...    0.618378
# max      2.626812  999.000000    2.631323  9985.000000  ...    2.943308
#
#              mvtf        levm        xvft        wlie        hrqg        ufpi  \
# count  375.000000  375.000000  375.000000  375.000000  375.000000  375.000000
# mean     0.813549    0.019861    0.025794    0.015583   -0.043098    0.022820
# std      0.522801    1.047218    1.056601    1.044524    1.013861    0.949319
# min     -0.015348   -2.858828   -3.021862   -2.518273   -3.235056   -2.932441
# 25%      0.428846   -0.637029   -0.668371   -0.746072   -0.725274   -0.620273
# 50%      0.810796    0.038377    0.045893   -0.029521   -0.070996    0.043922
# 75%      1.071240    0.703544    0.703272    0.714782    0.689616    0.622900
# max      2.906470    2.626787    2.958297    3.534230    3.037805    3.014764
#
#              txnv        ialq        amvq
# count  375.000000  375.000000  375.000000
# mean     0.031255   -0.089153   -0.803460
# std      1.002803    0.981380    0.565564
# min     -3.617318   -2.788141   -2.957366
# 25%     -0.641572   -0.746314   -1.065075
# 50%      0.047095   -0.035112   -0.759725
# 75%      0.718998    0.642919   -0.366072
# max      3.710121    2.487209   -0.000910
#
# [8 rows x 23 columns]

# %% [markdown]
# Using X_train.describe(), identify the two features with max values greater than 100. These features have scales that are quite different than the other features and must be scaled so that they share the same scale as the other features. Standardize one feature and Normalize the other feature.

# %%
# standardize feature
from sklearn.preprocessing import StandardScaler

feat = X_train._get_numeric_data().idxmax(1).iloc[0]
scaler = StandardScaler()
X_train[feat] = scaler.fit_transform(X_train[[feat]].values)
X_test[feat] = scaler.transform(X_test[[feat]].values)

# %%
# normalize feature
from sklearn.preprocessing import MinMaxScaler

feat = X_train._get_numeric_data().idxmax(1).iloc[0]
scaler = MinMaxScaler()
X_train[feat] = scaler.fit_transform(X_train[[feat]].values)
X_test[feat] = scaler.transform(X_test[[feat]].values)

# %%
# describe X_train again to verify transformations
X_train.describe()
# Out:
#              jmam        vhkq        bfze        msts        hvgk        zdku  \
# count  375.000000  375.000000  375.000000  375.000000  375.000000  375.000000
# mean    -0.052152    0.058521   -0.010869    0.013767    0.030813    0.036686
# std      0.965035    0.942168    0.943810    0.980027    1.006022    0.878809
# min     -3.081500   -4.019715   -2.938783   -2.478928   -2.696013   -3.042598
# 25%     -0.650450   -0.553456   -0.637562   -0.663000   -0.580452   -0.482225
# 50%     -0.087900    0.004336    0.009779   -0.038333   -0.010641    0.014956
# 75%      0.557150    0.650061    0.581011    0.655593    0.665284    0.593276
# max      2.892300    2.881825    2.788130    2.908620    2.862135    2.763532
#
#              oaug        bfgt        jycc          jjyc  ...        jngw  \
# count  375.000000  375.000000  375.000000  3.750000e+02  ...  375.000000
# mean    -0.039508    0.515921    0.848221  1.326346e-16  ...   -0.021014
# std      1.037949    0.298366    0.530156  1.001336e+00  ...    1.026857
# min     -3.047022    0.000000    0.012032 -1.680254e+00  ...   -3.212358
# 25%     -0.780126    0.250834    0.449896 -8.400537e-01  ...   -0.561123
# 50%     -0.027025    0.533927    0.836854 -2.138755e-02  ...   -0.043020
# 75%      0.682306    0.766963    1.171733  8.893554e-01  ...    0.618378
# max      2.626812    1.000000    2.631323  1.649731e+00  ...    2.943308
#
#              mvtf        levm        xvft        wlie        hrqg        ufpi  \
# count  375.000000  375.000000  375.000000  375.000000  375.000000  375.000000
# mean     0.813549    0.019861    0.025794    0.015583   -0.043098    0.022820
# std      0.522801    1.047218    1.056601    1.044524    1.013861    0.949319
# min     -0.015348   -2.858828   -3.021862   -2.518273   -3.235056   -2.932441
# 25%      0.428846   -0.637029   -0.668371   -0.746072   -0.725274   -0.620273
# 50%      0.810796    0.038377    0.045893   -0.029521   -0.070996    0.043922
# 75%      1.071240    0.703544    0.703272    0.714782    0.689616    0.622900
# max      2.906470    2.626787    2.958297    3.534230    3.037805    3.014764
#
#              txnv        ialq        amvq
# count  375.000000  375.000000  375.000000
# mean     0.031255   -0.089153   -0.803460
# std      1.002803    0.981380    0.565564
# min     -3.617318   -2.788141   -2.957366
# 25%     -0.641572   -0.746314   -1.065075
# 50%      0.047095   -0.035112   -0.759725
# 75%      0.718998    0.642919   -0.366072
# max      3.710121    2.487209   -0.000910
#
# [8 rows x 23 columns]

# %%
# X_train.info()
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 375 entries, 230 to 103
# Data columns (total 27 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   jmam       375 non-null    float64
#  1   vhkq       375 non-null    float64
#  2   bfze       375 non-null    float64
#  3   msts       375 non-null    float64
#  4   hvgk       375 non-null    float64
#  5   zdku       375 non-null    float64
#  6   oaug       375 non-null    float64
#  7   bfgt       375 non-null    float64
#  8   jycc       375 non-null    float64
#  9   jjyc       375 non-null    float64
#  10  setk       375 non-null    float64
#  11  ojap       375 non-null    float64
#  12  szif       375 non-null    float64
#  13  jngw       375 non-null    float64
#  14  mvtf       375 non-null    float64
#  15  levm       375 non-null    float64
#  16  xvft       375 non-null    float64
#  17  wlie       375 non-null    float64
#  18  hrqg       375 non-null    float64
#  19  ufpi       375 non-null    float64
#  20  txnv       375 non-null    float64
#  21  ialq       375 non-null    float64
#  22  amvq       375 non-null    float64
#  23  survival   375 non-null    object
#  24  treatment  375 non-null    object
#  25  level      375 non-null    object
#  26  stage      375 non-null    object
# dtypes: float64(23), object(4)
# memory usage: 82.0+ KB

# %%
# check for and fix outliers
for feat in X_train._get_numeric_data().columns[1:]:
    q1 = X_train[feat].quantile(0.25)
    q3 = X_train[feat].quantile(0.75)
    iqr = q3 - q1
    lower_fence = (q1 - 1.5 * iqr).round()
    upper_fence = (q3 + 1.5 * iqr).round()
    lower_count = X_train[feat][X_train[feat] < lower_fence].count()
    upper_count = X_train[feat][X_train[feat] > upper_fence].count()
    print(f'{feat} outliers = {lower_count + upper_count}: lower_fence: {lower_fence}, upper_fence: {upper_fence}, lower_count: {lower_count}, upper_count: {upper_count}')
# Out:
# vhkq outliers = 13: lower_fence: -2.0, upper_fence: 2.0, lower_count: 8, upper_count: 5
# bfze outliers = 16: lower_fence: -2.0, upper_fence: 2.0, lower_count: 8, upper_count: 8
# msts outliers = 0: lower_fence: -3.0, upper_fence: 3.0, lower_count: 0, upper_count: 0
# hvgk outliers = 10: lower_fence: -2.0, upper_fence: 3.0, lower_count: 10, upper_count: 0
# zdku outliers = 10: lower_fence: -2.0, upper_fence: 2.0, lower_count: 5, upper_count: 5
# oaug outliers = 2: lower_fence: -3.0, upper_fence: 3.0, lower_count: 2, upper_count: 0
# bfgt outliers = 0: lower_fence: -1.0, upper_fence: 2.0, lower_count: 0, upper_count: 0
# jycc outliers = 10: lower_fence: -1.0, upper_fence: 2.0, lower_count: 0, upper_count: 10
# jjyc outliers = 0: lower_fence: -3.0, upper_fence: 3.0, lower_count: 0, upper_count: 0
# setk outliers = 11: lower_fence: -2.0, upper_fence: 3.0, lower_count: 11, upper_count: 0
# ojap outliers = 15: lower_fence: -2.0, upper_fence: 2.0, lower_count: 5, upper_count: 10
# szif outliers = 10: lower_fence: -3.0, upper_fence: 2.0, lower_count: 0, upper_count: 10
# jngw outliers = 24: lower_fence: -2.0, upper_fence: 2.0, lower_count: 14, upper_count: 10
# mvtf outliers = 15: lower_fence: -1.0, upper_fence: 2.0, lower_count: 0, upper_count: 15
# levm outliers = 0: lower_fence: -3.0, upper_fence: 3.0, lower_count: 0, upper_count: 0
# xvft outliers = 2: lower_fence: -3.0, upper_fence: 3.0, lower_count: 2, upper_count: 0
# wlie outliers = 2: lower_fence: -3.0, upper_fence: 3.0, lower_count: 0, upper_count: 2
# hrqg outliers = 2: lower_fence: -3.0, upper_fence: 3.0, lower_count: 1, upper_count: 1
# ufpi outliers = 16: lower_fence: -2.0, upper_fence: 2.0, lower_count: 7, upper_count: 9
# txnv outliers = 2: lower_fence: -3.0, upper_fence: 3.0, lower_count: 1, upper_count: 1
# ialq outliers = 0: lower_fence: -3.0, upper_fence: 3.0, lower_count: 0, upper_count: 0
# amvq outliers = 16: lower_fence: -2.0, upper_fence: 1.0, lower_count: 16, upper_count: 0

# %%
# show correlation heat map for features, check for multicollinearity
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# correlation matrix
sns.set(style="white")

# compute the correlation matrix
corr = X_train._get_numeric_data().corr()

# generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True

# set up the matplotlib figure
# f, ax = plt.subplots()
f = plt.figure(figsize=(10, 10))

# generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True);

plt.tight_layout()

# %%
# https://gist.github.com/wjptak/88575bbc5dde446e1186ffd41475c0f1
# identify pairs of correlated features

hi_corr = []

def get_highly_correlated_pairs(df, features, threshold=0.5):
  corr_df = df[features].corr() # get correlations
  correlated_features = np.where(np.abs(corr_df) > threshold) # select ones above the abs threshold
  correlated_features = [(corr_df.iloc[x,y], x, y) for x, y in zip(*correlated_features) if x != y and x < y] # avoid duplication
  s_corr_list = sorted(correlated_features, key=lambda x: -abs(x[0])) # sort by correlation value

  if s_corr_list == []:
    print("There are no highly correlated features with correlation above", threshold)
  else:
    for v, i, j in s_corr_list:
      cols = df[features].columns
      # print ("%s and %s = %.3f" % (corr_df.index[i], corr_df.columns[j], v))
      hi_corr.append([corr_df.index[i], corr_df.index[j]])

get_highly_correlated_pairs(X_train._get_numeric_data(), X_train._get_numeric_data().columns)
# hi_corr

# %%
# delete one of the features out of the pair(s) that show multicollinearity
for pairs in hi_corr:
  # print(pairs[0])
  X_train.drop(pairs[0], axis=1, inplace=True)
  X_test.drop(pairs[0], axis=1, inplace=True)

# %%
# vif test
from statsmodels.stats.outliers_influence import variance_inflation_factor

X = X_train._get_numeric_data().dropna().copy()
# add constant
X.insert(0, 'const', 1)

# create dataframe to store vif information
vif = pd.DataFrame()
vif['Feature'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# remove constant (first row) and show vif dataframe
X.drop('const', axis=1, inplace=True)
vif = vif.iloc[1: , :]
vif
# Out:
#    Feature       VIF
# 1     jmam  1.086364
# 2     vhkq  1.064092
# 3     bfze  1.078226
# 4     msts  1.096729
# 5     hvgk  1.036683
# 6     zdku  1.082947
# 7     oaug  1.036458
# 8     bfgt  1.106187
# 9     jycc  1.087142
# 10    jjyc  1.087342
# 11    ojap  1.096289
# 12    szif  1.086176
# 13    jngw  1.053667
# 14    mvtf  1.076531
# 15    levm  1.054801
# 16    xvft  1.078231
# 17    wlie  1.066714
# 18    hrqg  1.066846
# 19    ufpi  1.087717
# 20    txnv  1.077995
# 21    ialq  1.092407
# 22    amvq  1.078600

# %%
# show correlation heat map for features, check for multicollinearity
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# correlation matrix
sns.set(style="white")

# compute the correlation matrix
corr = X_train._get_numeric_data().corr()

# generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True

# set up the matplotlib figure
# f, ax = plt.subplots()
f = plt.figure(figsize=(10, 10))

# generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True);

plt.tight_layout()

# %%
# correlation with target
X_train._get_numeric_data().corrwith(y_train).plot.bar(
        title = 'Correlation with Dependent Variable', rot = 90, grid = True);

# %% [markdown]
# ### Create the Models

# %%
# sklearn linear regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

lr_model = LinearRegression()
lr_model.fit(X_train._get_numeric_data(), y_train)
# lr_feat_coeffs = list(zip(X_train._get_numeric_data(), lr_model.coef_))
feats = ['const']
feats.extend(X_train._get_numeric_data().columns)
coefs = [lr_model.intercept_]
coefs.extend(lr_model.coef_)
d = {'Feature': feats, 'Coef': coefs}
lr_df = pd.DataFrame(d)
print(lr_df)

# test set prediction results
yhat = lr_model.predict(X_test._get_numeric_data())
print(f'MSE: {mean_squared_error(y_true=y_test, y_pred=yhat)}')
print(f'R-Squared: {r2_score(y_test, yhat)}')
# Out:
#    Feature       Coef
# 0    const   1.702371
# 1     jmam  95.553393
# 2     vhkq  11.838947
# 3     bfze  77.929176
# 4     msts  14.050904
# 5     hvgk  -0.041201
# 6     zdku   2.552706
# 7     oaug  -0.608623
# 8     bfgt   4.368603
# 9     jycc   0.926489
# 10    jjyc  -0.252789
# 11    ojap  98.541212
# 12    szif  90.857862
# 13    jngw  -0.977720
# 14    mvtf  -2.024678
# 15    levm  -1.084077
# 16    xvft  60.525855
# 17    wlie  21.593834
# 18    hrqg  97.088923
# 19    ufpi  41.648594
# 20    txnv   1.206302
# 21    ialq  -1.515188
# 22    amvq   2.626213
# MSE: 2821.3199238552625
# R-Squared: 0.9443801428327036

# %%
# statsmodel ols with summary
import statsmodels.api as sm

# features should have a constant or intercept
# X_train = sm.add_constant(X_train)
X_with_const = X_train._get_numeric_data().copy()
X_with_const.insert(0, 'const', 1)
ols_model = sm.OLS(y_train, X_with_const).fit()
print(ols_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.969
# Model:                            OLS   Adj. R-squared:                  0.967
# Method:                 Least Squares   F-statistic:                     497.8
# Date:                Thu, 19 Oct 2023   Prob (F-statistic):          5.28e-250
# Time:                        05:09:37   Log-Likelihood:                -1895.9
# No. Observations:                 375   AIC:                             3838.
# Df Residuals:                     352   BIC:                             3928.
# Df Model:                          22
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.7024      7.286      0.234      0.815     -12.626      16.031
# jmam          95.5534      2.188     43.662      0.000      91.249      99.858
# vhkq          11.8389      2.219      5.336      0.000       7.476      16.202
# bfze          77.9292      2.229     34.957      0.000      73.545      82.314
# msts          14.0509      2.165      6.489      0.000       9.792      18.309
# hvgk          -0.0412      2.051     -0.020      0.984      -4.074       3.992
# zdku           2.5527      2.399      1.064      0.288      -2.166       7.272
# oaug          -0.6086      1.987     -0.306      0.760      -4.517       3.300
# bfgt           4.3686      7.143      0.612      0.541      -9.679      18.416
# jycc           0.9265      3.985      0.232      0.816      -6.911       8.764
# jjyc          -0.2528      2.110     -0.120      0.905      -4.403       3.897
# ojap          98.5412      2.200     44.791      0.000      94.214     102.868
# szif          90.8579      2.081     43.658      0.000      86.765      94.951
# jngw          -0.9777      2.026     -0.483      0.630      -4.961       3.006
# mvtf          -2.0247      4.021     -0.503      0.615      -9.934       5.884
# levm          -1.0841      1.987     -0.546      0.586      -4.992       2.824
# xvft          60.5259      1.991     30.395      0.000      56.609      64.442
# wlie          21.5938      2.004     10.778      0.000      17.653      25.534
# hrqg          97.0889      2.064     47.032      0.000      93.029     101.149
# ufpi          41.6486      2.226     18.709      0.000      37.270      46.027
# txnv           1.2063      2.098      0.575      0.566      -2.920       5.332
# ialq          -1.5152      2.158     -0.702      0.483      -5.759       2.729
# amvq           2.6262      3.721      0.706      0.481      -4.692       9.944
# ==============================================================================
# Omnibus:                       51.152   Durbin-Watson:                   1.940
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              421.850
# Skew:                          -0.104   Prob(JB):                     2.49e-92
# Kurtosis:                       8.192   Cond. No.                         8.70
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# show the coefficient using linear algebra matrices
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import statsmodels.api as sm

# linalg needs constant that was inserted for OLS and we already have OLS model
print('Sklearn Linear Regression Model')
print(lr_df)
# print(lr_model.intercept_)
print()
print('StatsModel')
print(ols_model.params)
print()

X = X_with_const
y = y_train
print('Numpy Linear Algebra')
print('weights = ', np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y))
# Out:
# Sklearn Linear Regression Model
#    Feature       Coef
# 0    const   1.702371
# 1     jmam  95.553393
# 2     vhkq  11.838947
# 3     bfze  77.929176
# 4     msts  14.050904
# 5     hvgk  -0.041201
# 6     zdku   2.552706
# 7     oaug  -0.608623
# 8     bfgt   4.368603
# 9     jycc   0.926489
# 10    jjyc  -0.252789
# 11    ojap  98.541212
# 12    szif  90.857862
# 13    jngw  -0.977720
# 14    mvtf  -2.024678
# 15    levm  -1.084077
# 16    xvft  60.525855
# 17    wlie  21.593834
# 18    hrqg  97.088923
# 19    ufpi  41.648594
# 20    txnv   1.206302
# 21    ialq  -1.515188
# 22    amvq   2.626213
#
# StatsModel
# const     1.702371
# jmam     95.553393
# vhkq     11.838947
# bfze     77.929176
# msts     14.050904
# hvgk     -0.041201
# zdku      2.552706
# oaug     -0.608623
# bfgt      4.368603
# jycc      0.926489
# jjyc     -0.252789
# ojap     98.541212
# szif     90.857862
# jngw     -0.977720
# mvtf     -2.024678
# levm     -1.084077
# xvft     60.525855
# wlie     21.593834
# hrqg     97.088923
# ufpi     41.648594
# txnv      1.206302
# ialq     -1.515188
# amvq      2.626213
# dtype: float64
#
# Numpy Linear Algebra
# weights =  [ 1.70237086e+00  9.55533929e+01  1.18389465e+01  7.79291756e+01
#   1.40509038e+01 -4.12012453e-02  2.55270645e+00 -6.08623495e-01
#   4.36860271e+00  9.26488676e-01 -2.52788720e-01  9.85412118e+01
#   9.08578620e+01 -9.77719630e-01 -2.02467838e+00 -1.08407692e+00
#   6.05258549e+01  2.15938340e+01  9.70889226e+01  4.16485941e+01
#   1.20630249e+00 -1.51518815e+00  2.62621329e+00]

# %% [markdown]
# #### Lasso / l1 Regularization
#
# * $\alpha = \sum|w_i|$
# * Forces weak features to have zero coefficients
# * Performs feature selection
# * Models can be unstable (coefficients fluctuate significantly on data changes with correlated features)

# %%
# lasso regularization
# create X _get_numeric_data() without constant

X_reg=X_with_const.drop('const',axis=1).copy()
print(X_reg.columns)
X_reg_test=X_test[X_reg.columns]
print(X_reg_test.columns)
# Out:
# Index(['jmam', 'vhkq', 'bfze', 'msts', 'hvgk', 'zdku', 'oaug', 'bfgt', 'jycc',
#        'jjyc', 'ojap', 'szif', 'jngw', 'mvtf', 'levm', 'xvft', 'wlie', 'hrqg',
#        'ufpi', 'txnv', 'ialq', 'amvq'],
#       dtype='object')
# Index(['jmam', 'vhkq', 'bfze', 'msts', 'hvgk', 'zdku', 'oaug', 'bfgt', 'jycc',
#        'jjyc', 'ojap', 'szif', 'jngw', 'mvtf', 'levm', 'xvft', 'wlie', 'hrqg',
#        'ufpi', 'txnv', 'ialq', 'amvq'],
#       dtype='object')

# %%
# lasso regularization
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
X=scaler.fit_transform(X_reg)
y=y_train
lasso_feats=X_reg.columns
lasso=Lasso(alpha=5)
lasso.fit(X,y)

d={'Feature' : lasso_feats, 'Coef' : lasso.coef_}
lasso_df=pd.DataFrame(d)
print(lasso_df)
# Out:
#    Feature       Coef
# 0     jmam  87.381720
# 1     vhkq   6.104058
# 2     bfze  68.623517
# 3     msts   9.121426
# 4     hvgk   0.000000
# 5     zdku   0.000000
# 6     oaug  -0.000000
# 7     bfgt  -0.000000
# 8     jycc  -0.000000
# 9     jjyc  -0.000000
# 10    ojap  88.165813
# 11    szif  86.979323
# 12    jngw  -0.000000
# 13    mvtf  -0.000000
# 14    levm  -0.000000
# 15    xvft  58.018745
# 16    wlie  18.189150
# 17    hrqg  93.836072
# 18    ufpi  34.736888
# 19    txnv   0.000000
# 20    ialq  -0.000000
# 21    amvq   0.000000

# %% [markdown]
# #### Ridge / l2 Regularization
#
# * $\alpha = \sum w_i^2$
# * Spreads out coefficients more equally
# * Exposes correlated features (have similar coefficients)
# * Models are more stable (coefficients don't fluctuate as much on data changes with correlated features)

# %%
# ridge regularization

from sklearn.linear_model import Ridge

scaler = StandardScaler()

# .values is used to avoid warning about training on feature names
# UserWarning: X has feature names, but Ridge was fitted without feature names
X = scaler.fit_transform(X_reg.values)
X_reg_test = scaler.transform(X_reg_test.values)
y = y_train.values
y_reg_test = y_test.values

ridge_feats = X_reg.columns

ridge = Ridge(alpha=10)
ridge.fit(X,y)

d = {'Feature': ridge_feats, 'Coef': ridge.coef_}
ridge_df = pd.DataFrame(d)
print(ridge_df)
print()
print(f'Training Score: {ridge.score(X, y)}')
print(f'Test Score: {ridge.score(X_reg_test, y_reg_test)}')
# Out:
#    Feature       Coef
# 0     jmam  89.382508
# 1     vhkq  10.706609
# 2     bfze  71.652333
# 3     msts  13.756141
# 4     hvgk   0.309987
# 5     zdku   2.653224
# 6     oaug  -0.827121
# 7     bfgt   1.159491
# 8     jycc  -0.079846
# 9     jjyc  -0.488609
# 10    ojap  91.648474
# 11    szif  89.424415
# 12    jngw  -1.107240
# 13    mvtf  -1.166778
# 14    levm  -1.114871
# 15    xvft  62.073017
# 16    wlie  21.817345
# 17    hrqg  95.605261
# 18    ufpi  38.593969
# 19    txnv   1.243660
# 20    ialq  -1.899451
# 21    amvq   1.283516
#
# Training Score: 0.9680925531977774
# Test Score: 0.9447092668556658

# %%
# compare the coefficients from the linear regression, lasso, and ridge models
d = {'Original': X_reg.columns, 'Original Coeffs': lr_model.coef_.tolist(), 'Lasso': lasso_feats, 'Lasso Coeffs': lasso.coef_, 'Ridge': ridge_feats, 'Ridge Coeffs': ridge.coef_}
reg_df = pd.DataFrame(d)
print(reg_df[1:])
# Out:
#    Original  Original Coeffs Lasso  Lasso Coeffs Ridge  Ridge Coeffs
# 1      vhkq        11.838947  vhkq      6.104058  vhkq     10.706609
# 2      bfze        77.929176  bfze     68.623517  bfze     71.652333
# 3      msts        14.050904  msts      9.121426  msts     13.756141
# 4      hvgk        -0.041201  hvgk      0.000000  hvgk      0.309987
# 5      zdku         2.552706  zdku      0.000000  zdku      2.653224
# 6      oaug        -0.608623  oaug     -0.000000  oaug     -0.827121
# 7      bfgt         4.368603  bfgt     -0.000000  bfgt      1.159491
# 8      jycc         0.926489  jycc     -0.000000  jycc     -0.079846
# 9      jjyc        -0.252789  jjyc     -0.000000  jjyc     -0.488609
# 10     ojap        98.541212  ojap     88.165813  ojap     91.648474
# 11     szif        90.857862  szif     86.979323  szif     89.424415
# 12     jngw        -0.977720  jngw     -0.000000  jngw     -1.107240
# 13     mvtf        -2.024678  mvtf     -0.000000  mvtf     -1.166778
# 14     levm        -1.084077  levm     -0.000000  levm     -1.114871
# 15     xvft        60.525855  xvft     58.018745  xvft     62.073017
# 16     wlie        21.593834  wlie     18.189150  wlie     21.817345
# 17     hrqg        97.088923  hrqg     93.836072  hrqg     95.605261
# 18     ufpi        41.648594  ufpi     34.736888  ufpi     38.593969
# 19     txnv         1.206302  txnv      0.000000  txnv      1.243660
# 20     ialq        -1.515188  ialq     -0.000000  ialq     -1.899451
# 21     amvq         2.626213  amvq      0.000000  amvq      1.283516

# %%
# X_reg correlation with target
X_reg.corrwith(y_train).plot.bar(
    title='Correlation with Dependent Variable', rot=90,grid=True
);

# %%
# https://stackoverflow.com/questions/17778394/list-highest-correlation-pairs-from-a-large-correlation-matrix-in-pandas
corr_matrix = X_reg.corr().abs()
print(corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
                  .stack()
                  .sort_values(ascending=False))
# Out:
# vhkq  zdku    0.184600
# bfgt  ufpi    0.162444
# bfze  amvq    0.155440
# jycc  szif    0.149647
# msts  xvft    0.143092
#                 ...
# hrqg  amvq    0.001796
# msts  ufpi    0.001268
# zdku  xvft    0.000867
# bfze  jngw    0.000794
# oaug  jjyc    0.000220
# Length: 231, dtype: float64

# %%
# show correlation heat map for features, check for multicollinearity
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# correlation matrix
sns.set(style="white")

# compute the correlation matrix
corr = X_reg.corr()

# generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True

# set up the matplotlib figure
# f, ax = plt.subplots()
f = plt.figure(figsize=(10, 10))

# generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True);

plt.tight_layout()

# %%
# ols summary recall
print(ols_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.969
# Model:                            OLS   Adj. R-squared:                  0.967
# Method:                 Least Squares   F-statistic:                     497.8
# Date:                Thu, 19 Oct 2023   Prob (F-statistic):          5.28e-250
# Time:                        05:11:38   Log-Likelihood:                -1895.9
# No. Observations:                 375   AIC:                             3838.
# Df Residuals:                     352   BIC:                             3928.
# Df Model:                          22
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.7024      7.286      0.234      0.815     -12.626      16.031
# jmam          95.5534      2.188     43.662      0.000      91.249      99.858
# vhkq          11.8389      2.219      5.336      0.000       7.476      16.202
# bfze          77.9292      2.229     34.957      0.000      73.545      82.314
# msts          14.0509      2.165      6.489      0.000       9.792      18.309
# hvgk          -0.0412      2.051     -0.020      0.984      -4.074       3.992
# zdku           2.5527      2.399      1.064      0.288      -2.166       7.272
# oaug          -0.6086      1.987     -0.306      0.760      -4.517       3.300
# bfgt           4.3686      7.143      0.612      0.541      -9.679      18.416
# jycc           0.9265      3.985      0.232      0.816      -6.911       8.764
# jjyc          -0.2528      2.110     -0.120      0.905      -4.403       3.897
# ojap          98.5412      2.200     44.791      0.000      94.214     102.868
# szif          90.8579      2.081     43.658      0.000      86.765      94.951
# jngw          -0.9777      2.026     -0.483      0.630      -4.961       3.006
# mvtf          -2.0247      4.021     -0.503      0.615      -9.934       5.884
# levm          -1.0841      1.987     -0.546      0.586      -4.992       2.824
# xvft          60.5259      1.991     30.395      0.000      56.609      64.442
# wlie          21.5938      2.004     10.778      0.000      17.653      25.534
# hrqg          97.0889      2.064     47.032      0.000      93.029     101.149
# ufpi          41.6486      2.226     18.709      0.000      37.270      46.027
# txnv           1.2063      2.098      0.575      0.566      -2.920       5.332
# ialq          -1.5152      2.158     -0.702      0.483      -5.759       2.729
# amvq           2.6262      3.721      0.706      0.481      -4.692       9.944
# ==============================================================================
# Omnibus:                       51.152   Durbin-Watson:                   1.940
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              421.850
# Skew:                          -0.104   Prob(JB):                     2.49e-92
# Kurtosis:                       8.192   Cond. No.                         8.70
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# create a statsmodel ols model using the relevant features found in the Lasso model, print the summary

# statsmodel ols feature selection per l1 regularization

import statsmodels.api as sm

X_sel_feats=X_reg.drop(['ialq','levm'],axis=1)
X_sel_feats.insert(0,'constant',1)
sel_feats_model=sm.OLS(y_train,X_sel_feats).fit()
print(sel_feats_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.969
# Model:                            OLS   Adj. R-squared:                  0.967
# Method:                 Least Squares   F-statistic:                     549.4
# Date:                Thu, 19 Oct 2023   Prob (F-statistic):          1.40e-252
# Time:                        05:12:18   Log-Likelihood:                -1896.3
# No. Observations:                 375   AIC:                             3835.
# Df Residuals:                     354   BIC:                             3917.
# Df Model:                          20
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# constant       1.5264      7.260      0.210      0.834     -12.751      15.804
# jmam          95.7453      2.163     44.265      0.000      91.491      99.999
# vhkq          11.8296      2.214      5.343      0.000       7.476      16.184
# bfze          77.9299      2.222     35.079      0.000      73.561      82.299
# msts          14.2050      2.152      6.601      0.000       9.973      18.437
# hvgk           0.0870      2.041      0.043      0.966      -3.928       4.102
# zdku           2.6918      2.390      1.126      0.261      -2.008       7.392
# oaug          -0.4921      1.977     -0.249      0.804      -4.381       3.397
# bfgt           4.2257      7.099      0.595      0.552      -9.735      18.187
# jycc           1.4464      3.932      0.368      0.713      -6.287       9.180
# jjyc          -0.0836      2.096     -0.040      0.968      -4.206       4.039
# ojap          98.5841      2.194     44.925      0.000      94.268     102.900
# szif          90.9195      2.069     43.954      0.000      86.851      94.988
# jngw          -1.0161      2.021     -0.503      0.615      -4.991       2.959
# mvtf          -1.9940      4.014     -0.497      0.620      -9.888       5.900
# xvft          60.3692      1.979     30.510      0.000      56.478      64.261
# wlie          21.8293      1.979     11.028      0.000      17.936      25.722
# hrqg          97.0684      2.060     47.111      0.000      93.016     101.121
# ufpi          41.7138      2.214     18.838      0.000      37.359      46.069
# txnv           1.2103      2.093      0.578      0.563      -2.906       5.326
# amvq           2.7529      3.708      0.742      0.458      -4.540      10.046
# ==============================================================================
# Omnibus:                       51.108   Durbin-Watson:                   1.929
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              423.183
# Skew:                          -0.096   Prob(JB):                     1.28e-92
# Kurtosis:                       8.201   Cond. No.                         8.66
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Model Comparison
#
# Provide a comparison between the original OLS model and the reduced features OLS model created with the help of l1 regularization. Make mention of the following:
#
# * R-squared
# * Adj R-squared
# * F-statistic
# * AIC and BIC
# * The coefficients that are common in both models
# * The standard error for each coefficient
# * The t-statistic
# * The critical value
# * The p-value
# * The 95% confidence interval

# %%
# create, train, and test a model using a pipeline that includes a StandardScaler and a Lasso Regression model, output the training and testing scores

from sklearn.linear_model import Lasso
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

pipe = [
    ('scalar', StandardScaler()),
    ('model', Lasso(alpha=5, fit_intercept=True))
]

pipe_model = Pipeline(pipe)
pipe_model.fit(X_reg.values, y_train.values)

d = {'Feature': X_reg.columns, 'Coef': pipe_model['model'].coef_}
pipe_df = pd.DataFrame(d)
print(pipe_df)
print()
print(f'Training Score: {pipe_model.score(X_reg.values, y_train.values)}')
print(f'Test Score: {pipe_model.score(X_reg_test, y_reg_test)}')
print()
print(f'Training Score: {lasso.score(X, y)}')
print(f'Test Score: {lasso.score(X_reg_test, y_reg_test)}')
# Out:
#    Feature       Coef
# 0     jmam  87.381720
# 1     vhkq   6.104058
# 2     bfze  68.623517
# 3     msts   9.121426
# 4     hvgk   0.000000
# 5     zdku   0.000000
# 6     oaug  -0.000000
# 7     bfgt  -0.000000
# 8     jycc  -0.000000
# 9     jjyc  -0.000000
# 10    ojap  88.165813
# 11    szif  86.979323
# 12    jngw  -0.000000
# 13    mvtf  -0.000000
# 14    levm  -0.000000
# 15    xvft  58.018745
# 16    wlie  18.189150
# 17    hrqg  93.836072
# 18    ufpi  34.736888
# 19    txnv   0.000000
# 20    ialq  -0.000000
# 21    amvq   0.000000
#
# Training Score: 0.9629524218085754
# Test Score: 0.938265760760788
#
# Training Score: 0.9629524218085754
# Test Score: 0.9377472384021518

# %%
# compare
d = {'Original': X_reg.columns, 'Original Coef': lr_model.coef_.tolist(),
     'Lasso': lasso_feats, 'Lasso Coef': lasso.coef_,
     'Ridge': ridge_feats, 'Ridge Coef': ridge.coef_,
     'Pipe': X_reg.columns, 'Pipe Coef': pipe_model['model'].coef_}
reg_df = pd.DataFrame(d)
print(reg_df[1:])
# Out:
#    Original  Original Coef Lasso  Lasso Coef Ridge  Ridge Coef  Pipe  \
# 1      vhkq      11.838947  vhkq    6.104058  vhkq   10.706609  vhkq
# 2      bfze      77.929176  bfze   68.623517  bfze   71.652333  bfze
# 3      msts      14.050904  msts    9.121426  msts   13.756141  msts
# 4      hvgk      -0.041201  hvgk    0.000000  hvgk    0.309987  hvgk
# 5      zdku       2.552706  zdku    0.000000  zdku    2.653224  zdku
# 6      oaug      -0.608623  oaug   -0.000000  oaug   -0.827121  oaug
# 7      bfgt       4.368603  bfgt   -0.000000  bfgt    1.159491  bfgt
# 8      jycc       0.926489  jycc   -0.000000  jycc   -0.079846  jycc
# 9      jjyc      -0.252789  jjyc   -0.000000  jjyc   -0.488609  jjyc
# 10     ojap      98.541212  ojap   88.165813  ojap   91.648474  ojap
# 11     szif      90.857862  szif   86.979323  szif   89.424415  szif
# 12     jngw      -0.977720  jngw   -0.000000  jngw   -1.107240  jngw
# 13     mvtf      -2.024678  mvtf   -0.000000  mvtf   -1.166778  mvtf
# 14     levm      -1.084077  levm   -0.000000  levm   -1.114871  levm
# 15     xvft      60.525855  xvft   58.018745  xvft   62.073017  xvft
# 16     wlie      21.593834  wlie   18.189150  wlie   21.817345  wlie
# 17     hrqg      97.088923  hrqg   93.836072  hrqg   95.605261  hrqg
# 18     ufpi      41.648594  ufpi   34.736888  ufpi   38.593969  ufpi
# 19     txnv       1.206302  txnv    0.000000  txnv    1.243660  txnv
# 20     ialq      -1.515188  ialq   -0.000000  ialq   -1.899451  ialq
# 21     amvq       2.626213  amvq    0.000000  amvq    1.283516  amvq
#
#     Pipe Coef
# 1    6.104058
# 2   68.623517
# 3    9.121426
# 4    0.000000
# 5    0.000000
# 6   -0.000000
# 7   -0.000000
# 8   -0.000000
# 9   -0.000000
# 10  88.165813
# 11  86.979323
# 12  -0.000000
# 13  -0.000000
# 14  -0.000000
# 15  58.018745
# 16  18.189150
# 17  93.836072
# 18  34.736888
# 19   0.000000
# 20  -0.000000
# 21   0.000000

# %% [markdown]
# ## Assignment Summary
#
# Overall, I have studied, cleaned, and investigated this dataset, which contains variables that are unknown to me since the variables have been anonymized. There were a few more null values while cleaning the dataset, so I personally inspected it and then proceeded on to detect collinearity and multicollinearity, where certain attributes demonstrated substantial relationships. To address this issue, we deleted two sets of highly correlated characteristics, allowing us to effectively complete our analysis using the meansquare equation and the r square equation. Finally, we picked the four characteristics with the most statistically significant p-values in the Ordinary Least Squares (OLS) regression findings.
#
# Then, created a linear regression model and evaluated its efficacy using metrics like Mean Squared Error (MSE) and R-squared (R2). You also determined the model's intercept and coefficients, utilized a pairplot to show the data correlations, and more. You also developed an Ordinary Least Squares (OLS) model, calculating the coefficients and intercept using linear algebra.
#
# We applied the make_regression technique to mimic random data before converting the dataset into a dataframe. The dataframe was then trained with train test split.Shape, describe, and hist algorithms have been used on this training data.
#
# Histograms show that the data in X_train are both skewed and normal. We used median interpolation for the skewed data and the conventional method for the normal data. To remove multicollinearity, we eliminated one of the columns after determining the VIF for each variable.The correlation heat map's multicollinearity was eliminated.Then, after calculating the X_train to Target Y_train correlation, it can be shown that the mean and the target are closely related.
#
# In order to calculate the mean squared error, r-squared error, intercepts, and coefficients, we first developed a linear regression model. We then prepared a summary of our model, which has the same coefficients and r-squared values as the prior linear regression model. The squared values are utilized to reduce errors.
#
# The confidence interval, which is broad at the ends owing to a lack of data and narrows in the middle, is represented by the color spread in the pairplot, which we subsequently generated. The red line illustrates the correlation between the features.
#
# After that, we removed the constant before regularizing the dataset with Lasso and Ridge and comparing all of the coefficients. The relationship with the desired variable was subsequently found.I produced a heatmap based on those values. We performed lasso regularization feature selection after removing two values based on Lasso coefficients with zero values.
#
# We found that the coefficient of determination is R-squared. The probability of the F-statistic. AIC, all of the coefficients in the table below the summary, and also.
